# %% [markdown]
# <h1>Week 1 Seminar Notes</h1>
# <h2>Looking through the lecture lab</h2>
# <li>
#     <ul>Difference between errors and exception is that an error prevents the program from completing its task whilst exceptions are problems that interrupt the normal flow of the program.</ul>
#     <ul>Numpy focuses on mathematical calculations using n-dimensional arrays, Pandas is designed for structured data manipulation working with 2-d arrays and dataframes. Pandas does utilise Numpy but they are both for different uses.</ul>
#     <ul></ul>
# </li>
